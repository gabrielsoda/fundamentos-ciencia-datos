# %% [markdown]
# ##  Ejercicio N°5
#
# Usando los datos de **`listings_ba.csv`** de Buenos Aires, que se encuentran cargados en el campus, imputar los precios de alquiler faltantes empleando:
#
# 1. **Media y moda** de los datos no faltantes.
# 2. **Una medida de resumen** de su elección, agrupando por **barrio** y **tipo de habitación**.
# 3. **Los 10 puntos más cercanos** geográficamente a cada dato faltante, utilizando las **coordenadas**.
#
# En cada uno de los casos, indicar la **cantidad de datos** utilizados para la imputación.

# %%
import pandas as pd

df = pd.read_csv("/content/listings_ba.csv")

# %%
df.istype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-590eb952b33a> in <cell line: 0>()
# ----> 1 df.istype()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'istype'

# %%
columnas = pd.DataFrame({ "columnas": df.columns, "tipo de dato" : df.dtypes.values
})
columnas
# Out:
#                           columnas tipo de dato
# 0                               id        int64
# 1                             name       object
# 2                          host_id        int64
# 3                        host_name       object
# 4              neighbourhood_group      float64
# 5                    neighbourhood       object
# 6                         latitude      float64
# 7                        longitude      float64
# 8                        room_type       object
# 9                            price      float64
# 10                  minimum_nights        int64
# 11               number_of_reviews        int64
# 12                     last_review       object
# 13               reviews_per_month      float64
# 14  calculated_host_listings_count        int64
# 15                availability_365        int64
# 16           number_of_reviews_ltm        int64
# 17                         license       object

# %%
df.head(10)
# Out:
#        id                                          name   host_id  \
# 0   11508            Amazing Luxurious Apt-Palermo Soho     42762
# 1   14222  RELAX IN HAPPY HOUSE - PALERMO, BUENOS AIRES  87710233
# 2  317484                   Single Room in Palermo Soho   1621752
# 3   15074                         ROOM WITH RIVER SIGHT     59338
# 4  118070         Amazing view - GREAT Studio - Balcony    530261
# 5  317486                  Single Suite in Palermo Soho   1621752
# 6   16695                     DUPLEX LOFT 2 - SAN TELMO     64880
# 7  317509             Comfortable house in Buenos Aires   1624246
# 8   17993  TEMPORARY RENT CUTE APARTMENT IN MICROCENTRO     68689
# 9  118877             Entire Studio/apt in Buenos Aires    600320
#
#        host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0        Candela                  NaN        Palermo -34.58184  -58.42415
# 1          María                  NaN        Palermo -34.58617  -58.41036
# ...

# %%
nans = df.isna().sum()
print(nans)
# Out:
# id                                    0
# name                                  3
# host_id                               0
# host_name                             0
# neighbourhood_group               20085
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                               100
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        3831
# reviews_per_month                  3831
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           19672
# dtype: int64

# %%
df[df["name"].isna()]
# Out:
#            id name   host_id host_name  neighbourhood_group neighbourhood  \
# 550    910751  NaN   4886514      Nora                  NaN     San Telmo
# 1246  4983187  NaN  16372482   Liliana                  NaN       Almagro
# 1565  7435494  NaN  38932166    Carlos                  NaN    Colegiales
#
#       latitude  longitude        room_type    price  minimum_nights  \
# 550  -34.61883  -58.37503  Entire home/apt   4153.0               1
# 1246 -34.59788  -58.41547  Entire home/apt   7048.0               3
# 1565 -34.57793  -58.44121  Entire home/apt  33000.0              30
#
#       number_of_reviews last_review  reviews_per_month  \
# 550                 325  2022-12-12               2.79
# 1246                  0         NaN                NaN
# 1565                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 550                                1               146                     71
# ...

# %%
df['price'].isna().sum()
# Out:
# np.int64(100)

# %%
df['price'].mean()
# Out:
# np.float64(16479.106329747312)

# %%
df['price'].mode()
# Out:
# 0    8810.0
# Name: price, dtype: float64
